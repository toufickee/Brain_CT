# %%
import glob
import imageio 
import os
import statistics 
import numpy as np
import PIL
from PIL import Image
import cv2

# %%
image_path='C:/Users/toufick/Documents/Python Scripts/head_CT/head_ct'

# %%
all_img=[]
for i in glob.glob('C:/Users/toufick/Documents/Python Scripts/head_CT/head_ct/head_ct/*.png'):
    all_img.append(i)

# %%
len(all_img)
# Out:
# 200

# %%
arr = os.listdir('C:/Users/toufick/Documents/Python Scripts/head_CT/head_ct/head_ct/')
#print(arr)

# %%
import matplotlib.pyplot as plt

# %%
# plt.imshow('C:/Users/toufick/Documents/Python Scripts/head_CT/head_ct/head_ct/000.png',cmap='gray')
# plt.show()

# %%
import scipy.ndimage as ndi

# %%
j=0

# %%
for i in glob.glob('C:/Users/toufick/Documents/Python Scripts/head_CT/head_ct/head_ct/*.png'):
    im=imageio.imread(i)
    hist=ndi.histogram(im, 0, 255, 256)
    con=(im.mean()+im.max())/2
    mask=np.where(im>con,im, 1)
    #imageio.imwrite('processed\\'+i[-7]+'.png',mask)
    new_img='C:/Users/toufick/Documents/Python Scripts/processed/img'+str(j)+'.jpg'
    cv2.imwrite(new_img, mask) 
    j=j+1

# %%
for i in glob.glob('C:/Users/toufick/Documents/Python Scripts/head_CT/head_ct/head_ct/*.png'):
    im=imageio.imread(i)
    hist=ndi.histogram(im, 0, 255, 256)
    filt=ndi.gaussian_filter(im,sigma=10)
    #m=statistics.mean(hist)
    con=(im.mean()+im.max())/2
    seg=im>0
    #mask=np.where(im>con,im, 1)
    labels,nlabels=ndi.label(seg)
    plt.imshow(labels,cmap='gray')
    plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ...

# %%
type(i)
# Out:
# str

# %%
import cv2
